# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Your code goes here
import the_functions
import pandas as pd
import numpy as np

url=('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv')
data_1=pd.read_csv(url)
data_one=the_functions.run_all(data_1)

# %%
data_one
# Out:
#      customer             state gender             education  \
# 0     RB50392        Washington    nan                Master
# 1     QZ44356           Arizona      F              Bachelor
# 2     AI49188            Nevada      F              Bachelor
# 3     WW63253  Californiafornia      M              Bachelor
# 4     GA49547        Washington      M  High School or Below
# ...       ...               ...    ...                   ...
# 4003      NaN               NaN    nan                   nan
# 4004      NaN               NaN    nan                   nan
# 4005      NaN               NaN    nan                   nan
# 4006      NaN               NaN    nan                   nan
# 4007      NaN               NaN    nan                   nan
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                        0.00      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# ...

# %%
url=('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')
data_2=pd.read_csv(url)
data_two=the_functions.run_all(data_2)

# %%
data_two
# Out:
#     customer             state gender education  customer_lifetime_value  \
# 0    GS98873           Arizona      F  Bachelor                323912.47
# 1    CW49887  Californiafornia      F    Master                462680.11
# 2    MY31220  Californiafornia      F   College                899704.02
# 3    UH35128            Oregon      F   College               2580706.30
# 4    WH52799           Arizona      F   College                380812.21
# ..       ...               ...    ...       ...                      ...
# 991  HV85198           Arizona      M    Master                847141.75
# 992  BS91566           Arizona      F   College                543121.91
# 993  IL40123            Nevada      F   College                568964.41
# 994  MY32149  Californiafornia      F    Master                368672.38
# 995  SA91515  Californiafornia      M  Bachelor                399258.39
#
#      income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
url=('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv')
data_3=pd.read_csv(url)
data_three=the_functions.run_all(data_3)

# %%
data_three
# Out:
#      customer             state  customer_lifetime_value  \
# 0     SA25987        Washington              3479.137523
# 1     TB86706           Arizona              2502.637401
# 2     ZL73902            Nevada              3265.156348
# 3     KX23516  Californiafornia              4455.843406
# 4     FN77294  Californiafornia              7704.958480
# ...       ...               ...                      ...
# 7065  LA72316  Californiafornia             23405.987980
# 7066  PK87824  Californiafornia              3096.511217
# 7067  TD14365  Californiafornia              8163.890428
# 7068  UP19263  Californiafornia              7524.442436
# 7069  Y167826  Californiafornia              2611.836866
#
#                  education gender  income  monthly_premium_auto  \
# 0     High School or Below      M       0                   104
# 1                   Master      M       0                    66
# 2                 Bachelor      F   25820                    82
# ...

# %%
df=pd.concat([data_one, data_two, data_three], axis=0)

# %%
df
# Out:
#      customer             state gender             education  \
# 0     RB50392        Washington    nan                Master
# 1     QZ44356           Arizona      F              Bachelor
# 2     AI49188            Nevada      F              Bachelor
# 3     WW63253  Californiafornia      M              Bachelor
# 4     GA49547        Washington      M  High School or Below
# ...       ...               ...    ...                   ...
# 7065  LA72316  Californiafornia      M              Bachelor
# 7066  PK87824  Californiafornia      F               College
# 7067  TD14365  Californiafornia      M              Bachelor
# 7068  UP19263  Californiafornia      M               College
# 7069  Y167826  Californiafornia      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                0.000000e+00      0.0                1000.0
# 1                6.979536e+05      0.0                  94.0
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here
url=('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv')
df=pd.read_csv(url)
df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
(df['unnamed:_0']==df.index).unique() # the same, therefore I am dropping the column "unnamed"
# Out:
# array([ True])

# %%
df=df.drop('unnamed:_0', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10910 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   response                       10910 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective_to_date              10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
# ...

# %%
df.drop_duplicates(keep='last', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10467 entries, 1 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10467 non-null  object
#  1   state                          10467 non-null  object
#  2   customer_lifetime_value        10467 non-null  float64
#  3   response                       10467 non-null  object
#  4   coverage                       10467 non-null  object
#  5   education                      10467 non-null  object
#  6   effective_to_date              10467 non-null  object
#  7   employmentstatus               10467 non-null  object
#  8   gender                         10467 non-null  object
#  9   income                         10467 non-null  int64
#  10  location_code                  10467 non-null  object
#  11  marital_status                 10467 non-null  object
# ...

# %%
df['effective_to_date']=pd.to_datetime(df['effective_to_date'], format='%Y-%m-%d', errors='ignore')
df['month']=pd.to_datetime(df.month, format='%m').dt.strftime('%B')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10467 entries, 1 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10467 non-null  object
#  1   state                          10467 non-null  object
#  2   customer_lifetime_value        10467 non-null  float64
#  3   response                       10467 non-null  object
#  4   coverage                       10467 non-null  object
#  5   education                      10467 non-null  object
#  6   effective_to_date              10467 non-null  datetime64[ns]
#  7   employmentstatus               10467 non-null  object
#  8   gender                         10467 non-null  object
#  9   income                         10467 non-null  int64
#  10  location_code                  10467 non-null  object
#  11  marital_status                 10467 non-null  object
# ...

# %%
df.month.unique()
# Out:
# array(['January', 'February'], dtype=object)

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
pivot_df=df.pivot_table(index='sales_channel', values=['income'], aggfunc='sum')

# %%
pivot_df=pd.DataFrame(pivot_df)

# %%
pivot_df['income']=pivot_df['income'].apply(lambda x: round(x,2))

# %%
pivot_df #The agent and branch channel are the one having higher income
# Out:
#                   income
# sales_channel
# Agent          146531312
# Branch         109816196
# Call Center     77688156
# Web             58756076

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
df.groupby(['education','gender'])[['customer_lifetime_value']].mean()
# Out:
#                              customer_lifetime_value
# education            gender
# Bachelor             F                   7913.452862
#                      M                   7713.303475
# College              F                   7755.029922
#                      M                   8086.291367
# Doctor               F                   7369.591923
#                      M                   7414.859039
# High School or Below F                   8616.664839
#                      M                   8162.364059
# Master               F                   8226.362324
#                      M                   8154.605652

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
pivot_df1=df.pivot_table(index='policy_type', columns='month', values=['number_of_open_complaints'], aggfunc='sum')

# %%
long_format1=pd.DataFrame(pivot_df1)

# %%
long_format1
# Out:
#                number_of_open_complaints
# month                           February      January
# policy_type
# Corporate Auto                369.671110   419.282184
# Personal Auto                1398.841880  1671.378904
# Special Auto                   85.842561    83.689793

# %%
pd.melt(long_format1 , id_vars=['policy_type','month'], value_vars=['number_of_open_complaints'] , var_name='Indicator', value_name='amount')
#it is not possible to conver a pivot table in a long format???
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 pd.melt(long_format1 , id_vars=['policy_type','month'], value_vars=['number_of_open_complaints'] , var_name='Indicator', value_name='amount')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/melt.py:73, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      71         missing = Index(com.flatten(id_vars)).difference(cols)
#      72         if not missing.empty:
# ---> 73             raise KeyError(
#      74                 "The following 'id_vars' are not present "
#      75                 f"in the DataFrame: {list(missing)}"
#      76             )
#      77 else:
#      78     id_vars = []
#
# KeyError: "The following 'id_vars' are not present in the DataFrame: ['month', 'policy_type']"

# %%
long_format=pd.melt(df, id_vars=['policy_type','month'], value_vars=['number_of_open_complaints'] , var_name='Indicator', value_name='amount')

# %%
long_format
# Out:
#           policy_type     month                  Indicator    amount
# 0       Personal Auto   January  number_of_open_complaints  0.000000
# 1       Personal Auto  February  number_of_open_complaints  0.000000
# 2      Corporate Auto   January  number_of_open_complaints  0.000000
# 3       Personal Auto   January  number_of_open_complaints  0.384256
# 4       Personal Auto  February  number_of_open_complaints  0.000000
# ...               ...       ...                        ...       ...
# 10462   Personal Auto   January  number_of_open_complaints  0.384256
# 10463   Personal Auto   January  number_of_open_complaints  0.000000
# 10464  Corporate Auto  February  number_of_open_complaints  0.000000
# 10465   Personal Auto  February  number_of_open_complaints  4.000000
# 10466   Personal Auto   January  number_of_open_complaints  0.000000
#
# [10467 rows x 4 columns]
